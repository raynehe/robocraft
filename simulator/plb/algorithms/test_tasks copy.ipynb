# %%
# shared across tasks
from plb.optimizer.optim import Adam
from plb.engine.taichi_env import TaichiEnv
from plb.config.default_config import get_cfg_defaults, CN

import os
import cv2
import numpy as np
import taichi as ti
ti.init(arch=ti.gpu)
import matplotlib.pyplot as plt
from plb.config import load
from tqdm.notebook import tqdm
# Out:
# [Taichi] Starting on arch=cuda

# %%
task_name = 'ngrip'
env_type = '_fixed'

# gripper_fixed.yml
cfg = load(f"../envs/gripper{env_type}.yml") 
print(cfg)
env = TaichiEnv(cfg, nn=False, loss=False)
env.initialize()
state = env.get_state()

env.set_state(**state)
taichi_env = env
print(env.renderer.camera_pos)
env.renderer.camera_pos[0] = 0.5
env.renderer.camera_pos[1] = 2.5
env.renderer.camera_pos[2] = 0.5
env.renderer.camera_rot = (1.57, 0.0)

env.primitives.primitives[0].set_state(0, [0.3, 0.4, 0.5, 1, 0, 0, 0])
env.primitives.primitives[1].set_state(0, [0.7, 0.4, 0.5, 1, 0, 0, 0])

env.render('plt')

action_dim = taichi_env.primitives.action_dim
# Out:
# ENV:
#   loss:
#     soft_contact: False
#     target_path: envs/assets/Chopsticks3D-v1.npy
#     weight:
#       contact: 1
#       density: 10
#       sdf: 10
#   n_observed_particles: 200
# PRIMITIVES: [{'shape': 'Capsule', 'h': 0.2, 'r': 0.045, 'init_pos': '(0.35, 0.4, 0.5)', 'init_rot': '(1., 0., 0., 0.)', 'color': '(0.8, 0.8, 0.8)', 'friction': 1.0, 'action': {'dim': 6, 'scale': '(0.02, 0.02, 0.02, 0.04, 0.04, 0.04)'}}, {'shape': 'Capsule', 'h': 0.2, 'r': 0.045, 'init_pos': '(0.65, 0.4, 0.5)', 'init_rot': '(1., 0., 0., 0.)', 'color': '(0.8, 0.8, 0.8)', 'friction': 1.0, 'action': {'dim': 6, 'scale': '(0.02, 0.02, 0.02, 0.04, 0.04, 0.04)'}}, {'shape': 'Capsule', 'h': 0.13, 'r': 0.025, 'init_pos': '(0.5, 0.1, 0.5)', 'init_rot': '(1., 0., 0., 0.)', 'color': '(0.2, 0.2, 0.2)', 'friction': 15.0}]
# RENDERER:
#   bake_size: 6
#   camera_pos: (0.5, 1.2, 4.0)
#   camera_pos_1: (0.5, 2.5, 2.2)
#   camera_pos_2: (0.5, 2.5, 2.2)
#   camera_pos_3: (0.5, 2.5, 2.2)
#   camera_pos_4: (0.5, 2.5, 2.2)
#   camera_rot: (0.2, 0)
#   camera_rot_1: (0.8, 0.0)
#   camera_rot_2: (0.8, 0.0)
#   camera_rot_3: (0.8, 0.0)
#   camera_rot_4: (0.8, 0.0)
#   dx: 0.006666666666666667
#   image_res: (512, 512)
#   light_direction: (2.0, 1.0, 0.7)
#   max_num_particles: 1000000
#   max_ray_depth: 2
#   sdf_threshold: 0.20720000000000002
#   spp: 50
#   target_res: (64, 64, 64)
#   use_directional_light: False
#   use_roulette: False
#   voxel_res: (168, 168, 168)
# SHAPES: [{'shape': 'box', 'width': '(0.25, 0.2, 0.25)', 'init_pos': '(0.5, 0.1, 0.5)', 'n_particles': 20000, 'color': '((150<<8)+ (150<<16))'}]
# SIMULATOR:
#   E: 5000.0
#   dim: 3
#   dtype: float64
#   gravity: (0, -5, 0)
#   ground_friction: 100.0
#   max_steps: 1024
#   n_particles: 9000
#   nu: 0.2
#   quality: 1
#   yield_stress: 4000.0
# VARIANTS: [{'ENV': {'loss': {'target_path': 'envs/assets/gripper-v1.npy'}}}]
# Building primitive
# action:
#   dim: 6
#   scale: (0.02, 0.02, 0.02, 0.04, 0.04, 0.04)
# color: (0.8, 0.8, 0.8)
# friction: 1.0
# h: 0.2
# init_pos: (0.35, 0.4, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# r: 0.045
# shape: Capsule
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 6
#   scale: (0.02, 0.02, 0.02, 0.04, 0.04, 0.04)
# color: (0.8, 0.8, 0.8)
# friction: 1.0
# h: 0.2
# init_pos: (0.65, 0.4, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# r: 0.045
# shape: Capsule
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# Building primitive
# action:
#   dim: 0
#   scale: ()
# color: (0.2, 0.2, 0.2)
# friction: 15.0
# h: 0.13
# init_pos: (0.5, 0.1, 0.5)
# init_rot: (1.0, 0.0, 0.0, 0.0)
# lower_bound: (0.0, 0.0, 0.0)
# r: 0.025
# shape: Capsule
# upper_bound: (1.0, 1.0, 1.0)
# variations: None
# {'width': (0.25, 0.2, 0.25), 'init_pos': (0.5, 0.1, 0.5), 'n_particles': 20000, 'color': 9868800}
# Initialize Renderer
# bake_size: 6
# camera_pos: (0.5, 1.2, 4.0)
# camera_pos_1: (0.5, 2.5, 2.2)
# camera_pos_2: (0.5, 2.5, 2.2)
# camera_pos_3: (0.5, 2.5, 2.2)
# camera_pos_4: (0.5, 2.5, 2.2)
# camera_rot: (0.2, 0)
# camera_rot_1: (0.8, 0.0)
# camera_rot_2: (0.8, 0.0)
# camera_rot_3: (0.8, 0.0)
# camera_rot_4: (0.8, 0.0)
# dx: 0.006666666666666667
# image_res: (512, 512)
# light_direction: (2.0, 1.0, 0.7)
# max_num_particles: 1000000
# max_ray_depth: 2
# sdf_threshold: 0.20720000000000002
# spp: 50
# target_res: (64, 64, 64)
# use_directional_light: False
# use_roulette: False
# voxel_res: (168, 168, 168)
# [Taichi] materializing...
# [0.5 1.2 4. ]
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$15516] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$15518] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$15520] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@70] [$15547] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@70] [$15557] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$15910] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$15912] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$15914] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@70] [$15941] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@70] [$15951] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$16354] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$16356] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$16358] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@70] [$16385] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@70] [$16395] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$16978] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$16980] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@100] [$16982] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 482, in render
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@70] [$17009] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@70] [$17019] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.382] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25153] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25155] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25157] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@70] [$25184] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@70] [$25194] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25547] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25549] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25551] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@70] [$25578] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@70] [$25588] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25991] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25993] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$25995] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@70] [$26022] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@70] [$26032] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$26615] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$26617] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@100] [$26619] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 483, in render
#     depth = self.next_hit(pos, d)[0]
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 264, in next_hit
#     normal = ti.cast(self.primitives[i].normal(0, o + dist * d), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@70] [$26646] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@70] [$26656] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:46.383] [type_check.cpp:visit@71]

# %%
cwd = os.getcwd()
root_dir = cwd + "/../.."
print(f'root: {root_dir}')

task_params = {
    "mid_point": np.array([0.5, 0.14, 0.5, 0, 0, 0]),
    "sample_radius": 0.4,
    "len_per_grip": 30,
    "len_per_grip_back": 10,
    "floor_pos": np.array([0.5, 0, 0.5]),
    "n_shapes": 3, 
    "n_shapes_floor": 9,
    "n_shapes_per_gripper": 11,
    "gripper_mid_pt": int((11 - 1) / 2),
    "gripper_rate_limits": np.array([0.14, 0.06]), # ((0.4 * 2 - (0.23)) / (2 * 30), (0.4 * 2 - 0.15) / (2 * 30)),
    "p_noise_scale": 0.01,
}

if env_type == '':
    task_params["p_noise_scale"] = 0.03

print(f'p_noise_scale: {task_params["p_noise_scale"]}')
# Out:
# root: /home/rayne/code/robocraft/simulator/plb/algorithms/../..
# p_noise_scale: 0.01

# %%
def set_parameters(env: TaichiEnv, yield_stress, E, nu):
    env.simulator.yield_stress.fill(yield_stress)
    _mu, _lam = E / (2 * (1 + nu)), E * nu / ((1 + nu) * (1 - 2 * nu))  # Lame parameters
    env.simulator.mu.fill(_mu)
    env.simulator.lam.fill(_lam)


def update_camera(env):
    env.renderer.camera_pos[0] = 0.5
    env.renderer.camera_pos[1] = 2.5
    env.renderer.camera_pos[2] = 0.5
    env.renderer.camera_rot = (1.57, 0.0)
    env.render_cfg.defrost()
    env.render_cfg.camera_pos_1 = (0.5, 2.5, 2.2)
    env.render_cfg.camera_rot_1 = (0.8, 0.)
    env.render_cfg.camera_pos_2 = (2.4, 2.5, 0.2)
    env.render_cfg.camera_rot_2 = (0.8, 1.8)
    env.render_cfg.camera_pos_3 = (-1.9, 2.5, 0.2)
    env.render_cfg.camera_rot_3 = (0.8, -1.8)
    env.render_cfg.camera_pos_4 = (0.5, 2.5, -1.8)
    env.render_cfg.camera_rot_4 = (0.8, 3.14)


def update_primitive(env, prim1_list, prim2_list):
    env.primitives.primitives[0].set_state(0, prim1_list)
    env.primitives.primitives[1].set_state(0, prim2_list)


def save_files(env, rollout_dir, i):
    files = glob.glob(f"{root_dir}/dataset/{task_name}/{i:03d}/*")
    for f in files:
        os.remove(f)
        
    os.makedirs(f"{rollout_dir}/{i:03d}", exist_ok=True)
    with open(f"{rollout_dir}/{i:03d}"+"/cam_params.npy", 'wb') as f:
        ext1=env.renderer.get_ext(env.render_cfg.camera_rot_1, np.array(env.render_cfg.camera_pos_1))
        ext2=env.renderer.get_ext(env.render_cfg.camera_rot_2, np.array(env.render_cfg.camera_pos_2))
        ext3=env.renderer.get_ext(env.render_cfg.camera_rot_3, np.array(env.render_cfg.camera_pos_3))
        ext4=env.renderer.get_ext(env.render_cfg.camera_rot_4, np.array(env.render_cfg.camera_pos_4))
        intrinsic = env.renderer.get_int()
        cam_params = {'cam1_ext': ext1, 'cam2_ext': ext2, 'cam3_ext': ext3, 'cam4_ext': ext4, 'intrinsic': intrinsic}
        np.save(f, cam_params)


from transforms3d.quaternions import mat2quat
from transforms3d.axangles import axangle2mat
def random_rotate(mid_point, gripper1_pos, gripper2_pos, z_vec):
    mid_point = mid_point[:3]
    z_angle = np.random.uniform(0, np.pi)
    z_mat = axangle2mat(z_vec, z_angle, is_normalized=True)
    all_mat = z_mat
    quat = mat2quat(all_mat)
    return gripper1_pos, gripper2_pos, quat


def random_pose(task_name):
    p_noise_x = task_params["p_noise_scale"] * (np.random.randn() * 2 - 1)
    p_noise_z = task_params["p_noise_scale"] * (np.random.randn() * 2 - 1)
    if task_name == 'ngrip' or task_name == 'ngrip_3d':
        p_noise = np.clip(np.array([p_noise_x, 0, p_noise_z]), a_min=-0.1, a_max=0.1)
    else:
        raise NotImplementedError
    
    new_mid_point = task_params["mid_point"][:3] + p_noise

    rot_noise = np.random.uniform(0, np.pi)

    x1 = new_mid_point[0] - task_params["sample_radius"] * np.cos(rot_noise)
    z1 = new_mid_point[2] + task_params["sample_radius"] * np.sin(rot_noise)
    x2 = new_mid_point[0] + task_params["sample_radius"] * np.cos(rot_noise)
    z2 = new_mid_point[2] - task_params["sample_radius"] * np.sin(rot_noise)
    y = new_mid_point[1]
    z_vec = np.array([np.cos(rot_noise), 0, np.sin(rot_noise)])
    if task_name == 'ngrip':
        gripper1_pos = np.array([x1, y, z1])
        gripper2_pos = np.array([x2, y, z2])
        quat = np.array([1, 0, 0, 0])
    elif task_name == 'ngrip_3d':
        gripper1_pos, gripper2_pos, quat = random_rotate(new_mid_point, np.array([x1, y, z1]), np.array([x2, y, z2]), z_vec)
    else:
        raise NotImplementedError
    return np.concatenate([gripper1_pos, quat]), np.concatenate([gripper2_pos, quat]), rot_noise


def get_obs(env, n_particles, t=0):
    x = env.simulator.get_x(t)
    v = env.simulator.get_v(t)
    step_size = len(x) // n_particles
    return x[::step_size], v[::step_size]


def select_tool(env, width):
    env.primitives.primitives[0].r[None] = width
    env.primitives.primitives[1].r[None] = width

# %%
import glob
from datetime import datetime
from tqdm.notebook import tqdm

i = 0
n_vid = 5
suffix = ''
n_grips = 3
zero_pad = np.array([0,0,0])

time_now = datetime.now().strftime("%d-%b-%Y-%H:%M:%S.%f")
rollout_dir = f"{root_dir}/dataset/{task_name}{env_type}{suffix}_{time_now}"

while i < n_vid: 
    print(f"+++++++++++++++++++{i}+++++++++++++++++++++")
    env.set_state(**state)
    taichi_env = env    
    update_camera(env)
    set_parameters(env, yield_stress=200, E=5e3, nu=0.2) # 200， 5e3, 0.2 # 300, 800, 0.2
    update_primitive(env, [0.3, 0.4, 0.5, 1, 0, 0, 0], [0.7, 0.4, 0.5, 1, 0, 0, 0])
    save_files(env, rollout_dir, i)
    action_dim = env.primitives.action_dim
    imgs = [] 
    true_idx = 0
    for k in range(n_grips):
        print(k)
        prim1, prim2, cur_angle = random_pose(task_name)
        update_primitive(env, prim1, prim2)
        if 'small' in suffix:
            tool_size = 0.025
        else:
            tool_size = 0.045
        select_tool(env, tool_size)
        
        gripper_rate_limit = [(task_params['sample_radius'] * 2 - (task_params['gripper_rate_limits'][0] + 2 * tool_size)) / (2 * task_params['len_per_grip']),
                              (task_params['sample_radius'] * 2 - (task_params['gripper_rate_limits'][1] + 2 * tool_size)) / (2 * task_params['len_per_grip'])]
        rate = np.random.uniform(*gripper_rate_limit)
        actions = []
        counter = 0 
        mid_point = (prim1[:3] + prim2[:3]) / 2
        prim1_direction = mid_point - prim1[:3]
        prim1_direction = prim1_direction / np.linalg.norm(prim1_direction)
        while counter < task_params["len_per_grip"]:
            prim1_action = rate * prim1_direction
            actions.append(np.concatenate([prim1_action/0.02, zero_pad, -prim1_action/0.02, zero_pad]))
            counter += 1
        counter = 0
        while counter < task_params["len_per_grip_back"]:
            prim1_action = -rate * prim1_direction
            actions.append(np.concatenate([prim1_action/0.02, zero_pad, -prim1_action/0.02, zero_pad]))
            counter += 1

        actions = np.stack(actions)
            
        for idx, act in enumerate(tqdm(actions, total=actions.shape[0])):
            env.step(act)
            obs = get_obs(env, 300)
            x = obs[0][:300]
            
            primitive_state = [env.primitives.primitives[0].get_state(0), env.primitives.primitives[1].get_state(0)]

            img = env.render_multi(mode='rgb_array', spp=3)
            rgb, depth = img[0], img[1]

            os.system('mkdir -p ' + f"{rollout_dir}/{i:03d}")
            
            for num_cam in range(4):
                cv2.imwrite(f"{rollout_dir}/{i:03d}/{true_idx:03d}_rgb_{num_cam}.png", rgb[num_cam][..., ::-1])
            with open(f"{rollout_dir}/{i:03d}/{true_idx:03d}_depth_prim.npy", 'wb') as f:
                np.save(f, depth + primitive_state + [tool_size])
            with open(f"{rollout_dir}/{i:03d}/{true_idx:03d}_gtp.npy", 'wb') as f:
                np.save(f, x)
            true_idx += 1

        print(true_idx)
    
    os.system(f'ffmpeg -y -i {rollout_dir}/{i:03d}/%03d_rgb_0.png -c:v libx264 -vf fps=25 -pix_fmt yuv420p {rollout_dir}/{i:03d}/vid{i:03d}.mp4')
    i += 1
# Out:
# +++++++++++++++++++0+++++++++++++++++++++
# 0
#   0%|          | 0/40 [00:00<?, ?it/s]
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53420] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53422] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53424] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53426] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53428] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53430] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53432] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53434] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@100] [$53436] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:56.256] [type_check.cpp:visit@101]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$78558] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$78560] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$78562] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$78589] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$78599] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$78970] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$78972] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$78974] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$79001] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$79011] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$80313] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$80315] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$80317] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$80344] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$80354] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$80725] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$80727] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$80729] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$80756] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$80766] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$82068] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$82070] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$82072] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 93, in collide
#     dist = self.sdf(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$82099] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$82109] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$82480] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$82482] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@100] [$82484] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/mpm_simulator.py", line 198, in grid_op
#     v_out = self.primitives[i].collide(f, I * self.dx, v_out, self.dt)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 96, in collide
#     D = self.normal(f, grid_pos)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 79, in normal
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$82511] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@70] [$82521] Atomic add (f64 to f32) may lose precision, at
# [W 02/22/23 21:05:59.465] [type_check.cpp:visit@71]
#
# [W 02/22/23 21:06:03.532] [type_check.cpp:visit@100] [$111342] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:06:03.532] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 455, in render_multi
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:06:03.532] [type_check.cpp:visit@100] [$111344] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:06:03.532] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 455, in render_multi
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 253, in next_hit
#     dd = ti.cast(self.primitives[i].sdf(0, pp), ti.f32)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/primitive/primive_base.py", line 59, in sdf
#     grid_pos = inv_trans(grid_pos, self.position[f], self.rotation[f])
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/util.py", line 163, in wrapped
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/impl.py", line 201, in maybe_transform_ti_func_call_to_stmt
#     return func(*args, **kwargs)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/common_ops.py", line 227, in assign
#     return ti.assign(self, other)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/ops.py", line 131, in wrapped
#     return a.element_wise_writeback_binary(imp_foo, b)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/matrix.py", line 179, in element_wise_writeback_binary
#     ret.entries[i] = foo(self.entries[i], other.entries[i])
#
# [W 02/22/23 21:06:03.532] [type_check.cpp:visit@100] [$111346] Local store may lose precision (target = f32, value = f64) at
# [W 02/22/23 21:06:03.532] [type_check.cpp:visit@101]
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 455, in render_multi
#     contrib = self.trace(pos, d)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 50, in decorated
#     return fun.__call__(*args)
#   File "/home/rayne/anaconda3/envs/robocraft/lib/python3.8/site-packages/taichi/lang/kernel_impl.py", line 122, in __call__
#     ret = self.compiled(*args)
#   File "/home/rayne/code/robocraft/simulator/plb/engine/renderer/renderer.py", line 363, in trace
#     closest, normal, c, roughness, material = self.next_hit(pos, d)
# ...
# Output #0, mp4, to '/home/rayne/code/robocraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_22-Feb-2023-21:05:55.640816/001/vid001.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# +++++++++++++++++++2+++++++++++++++++++++
# 0
# frame=  120 fps=0.0 q=-1.0 Lsize=    3171kB time=00:00:04.68 bitrate=5549.9kbits/s speed=8.96x
# video:3169kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.044587%
# [libx264 @ 0x5601d3c4c8c0] frame I:1     Avg QP:27.38  size: 29867
# [libx264 @ 0x5601d3c4c8c0] frame P:112   Avg QP:27.45  size: 27112
# [libx264 @ 0x5601d3c4c8c0] frame B:7     Avg QP:27.52  size: 25457
# [libx264 @ 0x5601d3c4c8c0] consecutive B-frames: 91.7%  1.7%  0.0%  6.7%
# [libx264 @ 0x5601d3c4c8c0] mb I  I16..4:  2.3% 95.8%  1.9%
# [libx264 @ 0x5601d3c4c8c0] mb P  I16..4:  0.2% 54.0%  2.4%  P16..4: 13.6% 18.5% 11.2%  0.0%  0.0%    skip: 0.2%
# [libx264 @ 0x5601d3c4c8c0] mb B  I16..4:  0.3% 43.1%  1.3%  B16..8: 34.3%  6.2%  5.5%  direct: 7.6%  skip: 1.7%  L0:48.8% L1:46.4% BI: 4.8%
# [libx264 @ 0x5601d3c4c8c0] 8x8 transform intra:95.6% inter:47.1%
# [libx264 @ 0x5601d3c4c8c0] coded y,uvDC,uvAC intra: 98.2% 21.4% 6.4% inter: 73.7% 5.5% 3.0%
# [libx264 @ 0x5601d3c4c8c0] i16 v,h,dc,p:  5% 13% 52% 30%
# [libx264 @ 0x5601d3c4c8c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5%  5% 64%  5%  4%  4%  4%  4%  4%
# [libx264 @ 0x5601d3c4c8c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6%  6% 41% 10%  8%  8%  8%  7%  6%
# [libx264 @ 0x5601d3c4c8c0] i8c dc,h,v,p: 77% 11% 11%  1%
# [libx264 @ 0x5601d3c4c8c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5601d3c4c8c0] ref P L0: 35.9%  9.7% 32.2% 22.2%
# [libx264 @ 0x5601d3c4c8c0] ref B L0: 67.9% 28.0%  4.1%
# [libx264 @ 0x5601d3c4c8c0] ref B L1: 84.4% 15.6%
# [libx264 @ 0x5601d3c4c8c0] kb/s:5407.73
#   0%|          | 0/40 [00:00<?, ?it/s]
# 40
# 1
#   0%|          | 0/40 [00:00<?, ?it/s]
# 80
# 2
#   0%|          | 0/40 [00:00<?, ?it/s]
# 120
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/rayne/code/robocraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_22-Feb-2023-21:05:55.640816/002/%03d_rgb_0.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d4fcd6a8c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d4fcd6a8c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x55d4fcd6a8c0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/rayne/code/robocraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_22-Feb-2023-21:05:55.640816/002/vid002.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# +++++++++++++++++++3+++++++++++++++++++++
# 0
# frame=  120 fps=0.0 q=-1.0 Lsize=    3183kB time=00:00:04.68 bitrate=5572.1kbits/s speed=8.96x
# video:3182kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.045270%
# [libx264 @ 0x55d4fcd6a8c0] frame I:1     Avg QP:27.36  size: 30115
# [libx264 @ 0x55d4fcd6a8c0] frame P:110   Avg QP:27.46  size: 27267
# [libx264 @ 0x55d4fcd6a8c0] frame B:9     Avg QP:27.58  size: 25341
# [libx264 @ 0x55d4fcd6a8c0] consecutive B-frames: 90.0%  0.0%  0.0% 10.0%
# [libx264 @ 0x55d4fcd6a8c0] mb I  I16..4:  3.4% 94.2%  2.3%
# [libx264 @ 0x55d4fcd6a8c0] mb P  I16..4:  0.3% 54.6%  2.5%  P16..4: 13.5% 18.1% 10.8%  0.0%  0.0%    skip: 0.2%
# [libx264 @ 0x55d4fcd6a8c0] mb B  I16..4:  0.2% 41.9%  1.1%  B16..8: 34.0%  7.6%  5.5%  direct: 7.1%  skip: 2.5%  L0:47.8% L1:46.3% BI: 5.9%
# [libx264 @ 0x55d4fcd6a8c0] 8x8 transform intra:95.2% inter:50.3%
# [libx264 @ 0x55d4fcd6a8c0] coded y,uvDC,uvAC intra: 98.1% 22.3% 7.3% inter: 72.6% 5.2% 3.0%
# [libx264 @ 0x55d4fcd6a8c0] i16 v,h,dc,p:  6% 15% 58% 22%
# [libx264 @ 0x55d4fcd6a8c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5%  5% 64%  5%  4%  4%  4%  4%  4%
# [libx264 @ 0x55d4fcd6a8c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7%  6% 40% 10%  8%  8%  8%  7%  7%
# [libx264 @ 0x55d4fcd6a8c0] i8c dc,h,v,p: 76% 11% 11%  1%
# [libx264 @ 0x55d4fcd6a8c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55d4fcd6a8c0] ref P L0: 36.5%  9.6% 31.8% 22.0%
# [libx264 @ 0x55d4fcd6a8c0] ref B L0: 67.8% 26.1%  6.1%
# [libx264 @ 0x55d4fcd6a8c0] ref B L1: 82.8% 17.2%
# [libx264 @ 0x55d4fcd6a8c0] kb/s:5429.30
#   0%|          | 0/40 [00:00<?, ?it/s]
# 40
# 1
#   0%|          | 0/40 [00:00<?, ?it/s]
# 80
# 2
#   0%|          | 0/40 [00:00<?, ?it/s]
# 120
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/rayne/code/robocraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_22-Feb-2023-21:05:55.640816/003/%03d_rgb_0.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f5c59498c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f5c59498c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x55f5c59498c0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/rayne/code/robocraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_22-Feb-2023-21:05:55.640816/003/vid003.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# +++++++++++++++++++4+++++++++++++++++++++
# 0
# frame=  120 fps=0.0 q=-1.0 Lsize=    3177kB time=00:00:04.68 bitrate=5560.7kbits/s speed= 9.2x
# video:3175kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.045117%
# [libx264 @ 0x55f5c59498c0] frame I:1     Avg QP:27.46  size: 30383
# [libx264 @ 0x55f5c59498c0] frame P:109   Avg QP:27.46  size: 27167
# [libx264 @ 0x55f5c59498c0] frame B:10    Avg QP:27.62  size: 25933
# [libx264 @ 0x55f5c59498c0] consecutive B-frames: 88.3%  1.7%  0.0% 10.0%
# [libx264 @ 0x55f5c59498c0] mb I  I16..4:  5.2% 92.8%  2.1%
# [libx264 @ 0x55f5c59498c0] mb P  I16..4:  0.4% 54.6%  2.6%  P16..4: 13.5% 18.0% 10.7%  0.0%  0.0%    skip: 0.2%
# [libx264 @ 0x55f5c59498c0] mb B  I16..4:  0.4% 42.4%  1.8%  B16..8: 32.9%  7.6%  5.2%  direct: 7.6%  skip: 2.2%  L0:47.8% L1:46.0% BI: 6.2%
# [libx264 @ 0x55f5c59498c0] 8x8 transform intra:94.9% inter:49.4%
# [libx264 @ 0x55f5c59498c0] coded y,uvDC,uvAC intra: 98.2% 21.7% 6.8% inter: 72.2% 4.8% 2.6%
# [libx264 @ 0x55f5c59498c0] i16 v,h,dc,p:  4% 16% 59% 21%
# [libx264 @ 0x55f5c59498c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5%  5% 64%  5%  4%  4%  4%  4%  4%
# [libx264 @ 0x55f5c59498c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7%  6% 39% 10%  8%  9%  8%  7%  7%
# [libx264 @ 0x55f5c59498c0] i8c dc,h,v,p: 76% 11% 11%  1%
# [libx264 @ 0x55f5c59498c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f5c59498c0] ref P L0: 36.2%  9.5% 32.0% 22.2%
# [libx264 @ 0x55f5c59498c0] ref B L0: 67.6% 26.6%  5.8%
# [libx264 @ 0x55f5c59498c0] ref B L1: 82.9% 17.1%
# [libx264 @ 0x55f5c59498c0] kb/s:5418.16
#   0%|          | 0/40 [00:00<?, ?it/s]
# 40
# 1
#   0%|          | 0/40 [00:00<?, ?it/s]
# 80
# 2
#   0%|          | 0/40 [00:00<?, ?it/s]
# 120
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/tmp/build/80754af9/ffmpeg_1587154242452/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placeho --cc=/tmp/build/80754af9/ffmpeg_1587154242452/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from '/home/rayne/code/robocraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_22-Feb-2023-21:05:55.640816/004/%03d_rgb_0.png':
#   Duration: 00:00:04.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 512x512, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556cdf7648c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556cdf7648c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x556cdf7648c0] 264 - core 157 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/rayne/code/robocraft/simulator/plb/algorithms/../../dataset/ngrip_fixed_22-Feb-2023-21:05:55.640816/004/vid004.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 512x512, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  120 fps=0.0 q=-1.0 Lsize=    3182kB time=00:00:04.68 bitrate=5570.3kbits/s speed=9.52x
# video:3181kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.044793%
# [libx264 @ 0x556cdf7648c0] frame I:1     Avg QP:27.38  size: 30174
# [libx264 @ 0x556cdf7648c0] frame P:111   Avg QP:27.46  size: 27220
# [libx264 @ 0x556cdf7648c0] frame B:8     Avg QP:27.61  size: 25618
# [libx264 @ 0x556cdf7648c0] consecutive B-frames: 90.8%  0.0%  2.5%  6.7%
# [libx264 @ 0x556cdf7648c0] mb I  I16..4:  2.9% 95.2%  1.9%
# [libx264 @ 0x556cdf7648c0] mb P  I16..4:  0.5% 54.5%  2.7%  P16..4: 13.5% 17.9% 10.7%  0.0%  0.0%    skip: 0.2%
# [libx264 @ 0x556cdf7648c0] mb B  I16..4:  0.2% 42.5%  1.4%  B16..8: 34.1%  7.5%  5.2%  direct: 6.7%  skip: 2.4%  L0:50.4% L1:43.3% BI: 6.3%
# [libx264 @ 0x556cdf7648c0] 8x8 transform intra:94.5% inter:49.4%
# [libx264 @ 0x556cdf7648c0] coded y,uvDC,uvAC intra: 98.1% 22.3% 6.7% inter: 72.0% 5.0% 2.8%
# [libx264 @ 0x556cdf7648c0] i16 v,h,dc,p:  6% 18% 56% 21%
# [libx264 @ 0x556cdf7648c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  5%  4% 64%  5%  4%  4%  4%  4%  4%
# [libx264 @ 0x556cdf7648c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6%  6% 40% 10%  8%  8%  8%  7%  7%
# [libx264 @ 0x556cdf7648c0] i8c dc,h,v,p: 77% 11% 11%  1%
# [libx264 @ 0x556cdf7648c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x556cdf7648c0] ref P L0: 36.4%  9.7% 31.7% 22.2%
# [libx264 @ 0x556cdf7648c0] ref B L0: 66.3% 26.7%  7.0%
# [libx264 @ 0x556cdf7648c0] ref B L1: 86.2% 13.8%
# [libx264 @ 0x556cdf7648c0] kb/s:5427.57
